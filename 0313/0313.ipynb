# %% [markdown]
# >#### 문제 검색하기
# 주소창에 boj.kr/문제번호
#
# >#### 문제 채점하기
# 1. 제출 탭 클릭
#
# ![제출1.png](img/2024-03-11-20-35-40.png)
#
# 2. 언어 Python3로 변경, 코드 복사해 붙여넣기 후 제출
#
# ![제출2.png](img/2024-03-11-20-36-21.png)

# %% [markdown]
# >#### 문제 푸는 방법
# 테스트케이스의 예제 입력과 똑같이 입력을 받을 때,
#
# 문제의 조건에 맞춰 예제 출력과 똑같이 나오면 정답

# %% [markdown]
# ***
# ***
# ## 입출력 및 사칙연산

# %% [markdown]
# > ### 연습문제 1
# - 번호 : [2557](https://boj.kr/2557)
# - 참고자료 : [사용자 입출력](https://wikidocs.net/25)
#
# <br/>
#
# >>### Hello World
#
# 문제
# - Hello World!를 출력하시오.
#
# 입력
# - 없음
#
# 출력
# - Hello World!를 출력하시오.
#
# <br/>
#
# ##### 테스트 케이스
#
# 예제 출력 1
# ```python
# Hello World!
# ```
# ***

# %% [markdown]
# > ### 연습문제 2
# - 번호 : [2558](https://boj.kr/2558)
# - 참고자료 : [사용자 입출력](https://wikidocs.net/25), [사칙연산](https://wikidocs.net/12#_5)
#
# <br/>
#
# >>### A+B - 2
#
# 문제
# - 두 정수 A와 B를 입력받은 다음, A+B를 출력하는 프로그램을 작성하시오.
#
# 입력
# - 첫째 줄에 A, 둘째 줄에 B가 주어진다. (0 < A, B < 10)
#
# 출력
# - 첫째 줄에 A+B를 출력한다.
#
# <br/>
#
# ##### 테스트 케이스
#
# 예제 입력 1
# ```python
# 1
# 2
# ```
#
# 예제 출력 1
# ```python
# 3
# ```
# ***

# %% [markdown]
# > ### 연습문제 3
# - 번호 : [10869](https://boj.kr/10869)
# - 참고자료 : [map()](https://www.entity.co.kr/entry/57-%EC%98%88%EC%A0%9C%EA%B0%80-%EC%9E%88%EB%8A%94-map-%ED%95%A8%EC%88%98-%ED%8C%8C%EC%9D%B4%EC%8D%AC), [사칙연산](https://wikidocs.net/12#_5)
#
# <br/>
#
# >>### 사칙연산
#
# 문제
# - 두 자연수 A와 B가 주어진다. 이때, A+B, A-B, A*B, A/B(몫), A%B(나머지)를 출력하는 프로그램을 작성하시오.
#
# 입력
# - 두 자연수 A와 B가 주어진다. (1 ≤ A, B ≤ 10,000)
#
# 출력
# - 첫째 줄에 A+B, 둘째 줄에 A-B, 셋째 줄에 A*B, 넷째 줄에 A/B, 다섯째 줄에 A%B를 출력한다.
#
# <br/>
#
# ##### 테스트 케이스
#
# 예제 입력 1
# ```python
# 7 3
# ```
#
# 예제 출력 1
# ```python
# 10
# 4
# 21
# 2
# 1
# ```
# ***

# %% [markdown]
# ## 조건문

# %% [markdown]
# > ### 연습문제 4
# - 번호 : [1330](https://boj.kr/1330)
# - 참고자료 : [if문](https://wikidocs.net/20)
#
# <br/>
#
# >>### 두 수 비교하기
#
# ##### 문제
# - 두 정수 A와 B가 주어졌을 때, A와 B를 비교하는 프로그램을 작성하시오.
#
# 입력
# - 첫째 줄에 A와 B가 주어진다. A와 B는 공백 한 칸으로 구분되어져 있다.
#
# 출력
# - 첫째 줄에 다음 세 가지 중 하나를 출력한다.
#
#   - A가 B보다 큰 경우에는 '>'를 출력한다.
#   - A가 B보다 작은 경우에는 '<'를 출력한다.
#   - A와 B가 같은 경우에는 '=='를 출력한다.
#
# 제한
# - -10,000 ≤ A, B ≤ 10,000
#
# <br/>
#
# ##### 테스트 케이스
#
# 예제 입력 1
# ```python
# 1 2
# ```
#
# 예제 출력 1
# ```python
# <
# ```
#
# <br/>
#
# 예제 입력 2
# ```python
# 10 2
# ```
#
# 예제 출력 2
# ```python
# >
# ```
#
# <br/>
#
# 예제 입력 3
# ```python
# 5 5
# ```
#
# 예제 출력 3
# ```python
# ==
# ```
#
# ***

# %% [markdown]
# > ### 연습문제 5
# - 번호 : [14681](https://boj.kr/14681)
# - 참고자료 : [if문](https://wikidocs.net/20)
#
# >>### 사분면 고르기
#
# ##### 문제
# - 흔한 수학 문제 중 하나는 주어진 점이 어느 사분면에 속하는지 알아내는 것이다. 사분면은 아래 그림처럼 1부터 4까지 번호를 갖는다. "Quadrant n"은 "제n사분면"이라는 뜻이다.
#
# ![](img/2024-03-12-09-54-45.png)
#
# 입력
# - 첫 줄에는 정수 x가 주어진다. (−1000 ≤ x ≤ 1000; x ≠ 0) 다음 줄에는 정수 y가 주어진다. (−1000 ≤ y ≤ 1000; y ≠ 0)
#
# 출력
# - 점 (x, y)의 사분면 번호(1, 2, 3, 4 중 하나)를 출력한다.
#
# <br/>
#
# ##### 테스트 케이스
#
# 예제 입력 1
# ```python
# 12
# 5
# ```
#
# 예제 출력 1
# ```python
# 1
# ```
# <br/>
#
# 예제 입력 2
# ```python
# 9
# -13
# ```
#
# 예제 출력 2
# ```python
# 4
# ```
# ***

# %% [markdown]
# ## 반복문

# %% [markdown]
# > ### 연습문제 6
# - 번호 : [2739](https://boj.kr/2739)
# - 참고자료 : [for문](https://wikidocs.net/22)
#
# <br/>
#
# >>### 구구단
#
# ##### 문제
# - N을 입력받은 뒤, 구구단 N단을 출력하는 프로그램을 작성하시오. 출력 형식에 맞춰서 출력하면 된다.
#
# 입력
# - 첫째 줄에 N이 주어진다. N은 1보다 크거나 같고, 9보다 작거나 같다.
#
# 출력
#
# ```
# - 출력형식과 같게 N*1부터 N*9까지 출력한다.
# ```
# <br/>
#
# ##### 테스트 케이스
#
# 예제 입력 1
# ```python
# 2
# ```
#
# 예제 출력 1
# ```python
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18
# ```
#
# ***

# %% [markdown]
# > ### 연습문제 7
# - 번호 : [10950](https://boj.kr/10950)
# - 참고자료 : [for문](https://wikidocs.net/22)
#
# <br/>
#
# >>### A+B - 3
#
# ##### 문제
# - 두 정수 A와 B를 입력받은 다음, A+B를 출력하는 프로그램을 작성하시오.
#
# 입력
# - 첫째 줄에 테스트 케이스의 개수 T가 주어진다.
#
# 각 테스트 케이스는 한 줄로 이루어져 있으며, 각 줄에 A와 B가 주어진다. (0 < A, B < 10)
#
# 출력
# - 각 테스트 케이스마다 A+B를 출력한다.
#
# <br/>
#
# ##### 테스트 케이스
#
# 예제 입력 1
# ```python
# 5
# 1 1
# 2 3
# 3 4
# 9 8
# 5 2
# ```
#
# 예제 출력 1
# ```python
# 2
# 5
# 7
# 17
# 7
# ```
#
# ***
